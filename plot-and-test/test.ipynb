# %%
import pandas as pd

# %%
X_test = pd.read_csv('test.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

f, axarr = plt.subplots(5, 5)

for i in range(5):
    for j in range(5):
        axarr[i, j].imshow(X_test.loc[[5 * i + j]].values.reshape(28, 28))
